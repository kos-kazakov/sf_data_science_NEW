# %%
import pandas as pd
import category_encoders as ce
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
data = pd.read_csv('data/wine_cleared.csv')

# %%
data['price_round'] = data['price'].round().astype(int)

# %%
regex = '\d{4}' # регулярное выражение для нахождения чисел
data['year'] = data['title'].str.findall(regex).str.get(0)

# %%
data['is_usa'] = data['country'].apply(lambda x: 1 if x == 'US' else 0)

# %%
data['country'].value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Serbia                       12
# Czech Republic               12
# Macedonia                    12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Bosnia and Herzegovina        2
# Armenia                       2
# Slovakia                      1
# China                         1
# Egypt                         1
# Name: country, dtype: int64

# %%
data['is_france'] = data['country'].apply(lambda x: 1 if x == 'France' else 0)
data['is_italy'] = data['country'].apply(lambda x: 1 if x == 'Italy' else 0)

# %%
display(data['is_france'].sum())
display(data['is_italy'].sum())
# Out:
# 22093
# 19540

# %%
data['old_wine'] = data['year'].apply(lambda x: 1 if float(x) < 2010 else 0)

# %%
data['old_wine'].sum()
# Out:
# 39781

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
#  13  price_round            129971 non-null  int32
#  14  year                   125362 non-null  object
#  15  is_usa                 129971 non-null  int64
#  16  is_france              129971 non-null  int64
#  17  is_italy               129971 non-null  int64
#  18  old_wine               129971 non-null  int64
# dtypes: float64(1), int32(1), int64(6), object(11)
# memory usage: 18.3+ MB

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\kkaza\AppData\Local\Temp\ipykernel_14240\1119197534.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <AxesSubplot: >

# %%
# Построим график корреляции всех величин. Для простоты воспользуемся корреляцией Пирсона.
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# C:\Users\kkaza\AppData\Local\Temp\ipykernel_14240\1803289335.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, ax=ax)
# <AxesSubplot: >

# %%
# Удалим самые сильно скоррелированные пары
data = data.drop(['is_usa', 'is_france', 'is_italy', 'price_round'], axis=1)

# %%
# Проверяем, что сильно скоррелированных признаков не осталось
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, linewidths=.5, ax=ax)
# Out:
# C:\Users\kkaza\AppData\Local\Temp\ipykernel_14240\1803289335.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, ax=ax)
# <AxesSubplot: >

# %%
regex_2 = '\((.*?)\)' 
data['locality'] = data['title'].str.findall(regex_2).str.get(0)

# %%
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129967                                 unknown      90  75.000000
# 129968                                   Kritt      90  30.000000
# 129969                                 unknown      90  32.000000
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro              unknown          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel              unknown  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  \
# 0               @kerinokeefe
# 1                 @vossroger
# 2                @paulgwine
# 3                    unknown
# 4                @paulgwine
# ...                      ...
# 129966               unknown
# 129967           @paulgwine
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery  price_round  year  is_usa  \
# 0                                        Nicosia           35  2013       0
# 1                            Quinta dos Avidagos           15  2011       0
# 2                                      Rainstorm           14  2013       1
# 3                                     St. Julian           13  2013       1
# 4                                   Sweet Cheeks           65  2012       1
# ...                                          ...          ...   ...     ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)           28  2013       0
# 129967                                  Citation           75  2004       1
# 129968                           Domaine Gresser           30  2013       0
# 129969                      Domaine Marcel Deiss           32  2012       0
# 129970                          Domaine Schoffit           21  2012       0
#
#         is_france  is_italy  old_wine                locality
# 0               0         1         0                    Etna
# 1               0         0         0                   Douro
# 2               0         0         0       Willamette Valley
# 3               0         0         0     Lake Michigan Shore
# 4               0         0         0       Willamette Valley
# ...           ...       ...       ...                     ...
# 129966          0         0         0  Erben Müller-Burggraef
# 129967          0         0         1                  Oregon
# 129968          1         0         0                  Alsace
# 129969          1         0         0                  Alsace
# 129970          1         0         0                  Alsace
#
# [129971 rows x 20 columns]

# %%
country_population = pd.read_csv('data/country_population.csv', sep=';')

country_population
# Out:
#               country     population
# 0               China  1,411,778,724
# 1               India  1,386,584,581
# 2                  US    333,022,386
# 3           Indonesia    271,350,000
# 4            Pakistan    225,200,000
# ..                ...            ...
# 236              Niue          1,549
# 237           Tokelau          1,501
# 238      Vatican City            825
# 239     Cocos Islands            573
# 240  Pitcairn Islands             40
#
# [241 rows x 2 columns]

# %%
country_population[country_population['country'] == 'Italy']
# Out:
#    country  population
# 24   Italy  59,097,904

# %%
data = data.join(country_population.set_index('country'), on='country')
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129967                                 unknown      90  75.000000
# 129968                                   Kritt      90  30.000000
# 129969                                 unknown      90  32.000000
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro              unknown          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel              unknown  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  ...         variety  \
# 0               @kerinokeefe  ...     White Blend
# 1                 @vossroger  ...  Portuguese Red
# 2                @paulgwine   ...      Pinot Gris
# 3                    unknown  ...        Riesling
# 4                @paulgwine   ...      Pinot Noir
# ...                      ...  ...             ...
# 129966               unknown  ...        Riesling
# 129967           @paulgwine   ...      Pinot Noir
# 129968            @vossroger  ...  Gewürztraminer
# 129969            @vossroger  ...      Pinot Gris
# 129970            @vossroger  ...  Gewürztraminer
#
#                                           winery price_round  year is_usa  \
# 0                                        Nicosia          35  2013      0
# 1                            Quinta dos Avidagos          15  2011      0
# 2                                      Rainstorm          14  2013      1
# 3                                     St. Julian          13  2013      1
# 4                                   Sweet Cheeks          65  2012      1
# ...                                          ...         ...   ...    ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)          28  2013      0
# 129967                                  Citation          75  2004      1
# 129968                           Domaine Gresser          30  2013      0
# 129969                      Domaine Marcel Deiss          32  2012      0
# 129970                          Domaine Schoffit          21  2012      0
#
#         is_france  is_italy  old_wine                locality   population
# 0               0         1         0                    Etna   59,097,904
# 1               0         0         0                   Douro   10,347,892
# 2               0         0         0       Willamette Valley  333,022,386
# 3               0         0         0     Lake Michigan Shore  333,022,386
# 4               0         0         0       Willamette Valley  333,022,386
# ...           ...       ...       ...                     ...          ...
# 129966          0         0         0  Erben Müller-Burggraef   83,129,285
# 129967          0         0         1                  Oregon  333,022,386
# 129968          1         0         0                  Alsace   68,035,000
# 129969          1         0         0                  Alsace   68,035,000
# 129970          1         0         0                  Alsace   68,035,000
#
# [129972 rows x 21 columns]

# %%
country_area = pd.read_csv('data/country_area.csv', sep=';')
country_area
# Out:
#           country         area
# 0          Russia  17075400.00
# 1          Canada   9984670.00
# 2           China   9596960.00
# 3              US   9372610.00
# 4          Brazil   8547000.00
# ..            ...          ...
# 188    San Marino        61.00
# 189        Tuvalu        26.00
# 190         Nauru        21.00
# 191        Monaco         2.00
# 192  Vatican City         0.44
#
# [193 rows x 2 columns]

# %%
data = data.join(country_area.set_index('country'), on='country')
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129967                                 unknown      90  75.000000
# 129968                                   Kritt      90  30.000000
# 129969                                 unknown      90  32.000000
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro              unknown          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel              unknown  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  ...                                    winery  \
# 0               @kerinokeefe  ...                                   Nicosia
# 1                 @vossroger  ...                       Quinta dos Avidagos
# 2                @paulgwine   ...                                 Rainstorm
# 3                    unknown  ...                                St. Julian
# 4                @paulgwine   ...                              Sweet Cheeks
# ...                      ...  ...                                       ...
# 129966               unknown  ...  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967           @paulgwine   ...                                  Citation
# 129968            @vossroger  ...                           Domaine Gresser
# 129969            @vossroger  ...                      Domaine Marcel Deiss
# 129970            @vossroger  ...                          Domaine Schoffit
#
#        price_round  year  is_usa is_france  is_italy  old_wine  \
# 0               35  2013       0         0         1         0
# 1               15  2011       0         0         0         0
# 2               14  2013       1         0         0         0
# 3               13  2013       1         0         0         0
# 4               65  2012       1         0         0         0
# ...            ...   ...     ...       ...       ...       ...
# 129966          28  2013       0         0         0         0
# 129967          75  2004       1         0         0         1
# 129968          30  2013       0         1         0         0
# 129969          32  2012       0         1         0         0
# 129970          21  2012       0         1         0         0
#
#                       locality   population       area
# 0                         Etna   59,097,904   301230.0
# 1                        Douro   10,347,892    92391.0
# 2            Willamette Valley  333,022,386  9372610.0
# 3          Lake Michigan Shore  333,022,386  9372610.0
# 4            Willamette Valley  333,022,386  9372610.0
# ...                        ...          ...        ...
# 129966  Erben Müller-Burggraef   83,129,285   357022.0
# 129967                  Oregon  333,022,386  9372610.0
# 129968                  Alsace   68,035,000   547030.0
# 129969                  Alsace   68,035,000   547030.0
# 129970                  Alsace   68,035,000   547030.0
#
# [129972 rows x 22 columns]

# %%
data[data['title'] == 'Gård 2014 Grand Klasse Reserve Lawrence Vineyards Viognier (Columbia Valley (WA))']['area']
# Out:
# 94    9372610.0
# Name: area, dtype: float64

# %%
# инициализируем информацию о звонках
calls_list = [
    [460, '2013-12-17 04:55:39', '2013-12-17 04:55:44', '2013-12-17 04:55:45'],
    [12, '2013-12-16 20:03:20', '2013-12-16 20:03:22', '2013-12-16 20:07:13'],
    [56, '2013-12-16 20:03:20', '2013-12-16 20:03:20', '2013-12-16 20:05:04'],
    [980, '2013-12-16 20:03:20','2013-12-16 20:03:27', '2013-12-16 20:03:29'],
    [396, '2013-12-16 20:08:27', '2013-12-16 20:08:28','2013-12-16 20:12:03'],
    [449, '2013-12-16 20:03:20', '2013-12-16 20:03:25','2013-12-16 20:05:00'],
    [397, '2013-12-16 20:08:25', '2013-12-16 20:08:27', '2013-12-16 20:09:59'],
    [398, '2013-12-16 20:01:23', '2013-12-16 20:01:23', '2013-12-16 20:04:58'],
    [452, '2013-12-16 20:03:20', '2013-12-16 20:03:21','2013-12-16 20:04:55'],
    [440, '2013-12-16 20:03:20', '2013-12-16 20:04:26', '2013-12-16 20:04:32']
]

calls = pd.DataFrame(calls_list, columns = ['client_id',  'agent_date', 'created_at' ,'end_date'])

# преобразовываем признаки в формат datetime для удобной работы

calls['agent_date'] = pd.to_datetime(calls['agent_date'])
calls['created_at'] = pd.to_datetime(calls['created_at'])
calls['end_date'] = pd.to_datetime(calls['end_date'])

calls
# Out:
#    client_id          agent_date          created_at            end_date
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32

# %%
calls['duration'] = (calls['end_date'] - calls['created_at']).dt.seconds
calls
# Out:
#    client_id          agent_date          created_at            end_date  \
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32
#
#    duration
# 0         1
# 1       231
# 2       104
# 3         2
# 4       215
# 5        95
# 6        92
# 7       215
# 8        94
# 9         6

# %%
calls['time_connection'] = (calls['created_at'] - calls['agent_date']).dt.seconds
calls
# Out:
#    client_id          agent_date          created_at            end_date  \
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32
#
#    duration  time_connection
# 0         1                5
# 1       231                2
# 2       104                0
# 3         2                7
# 4       215                1
# 5        95                5
# 6        92                2
# 7       215                0
# 8        94                1
# 9         6               66

# %%
calls['time_connection'].sum()
# Out:
# 89

# %%
calls['is_connection'] = calls['duration'].apply(lambda x: 1 if x>10 else 0)
calls
# Out:
#    client_id          agent_date          created_at            end_date  \
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32
#
#    duration  time_connection  is_connection
# 0         1                5              0
# 1       231                2              1
# 2       104                0              1
# 3         2                7              0
# 4       215                1              1
# 5        95                5              1
# 6        92                2              1
# 7       215                0              1
# 8        94                1              1
# 9         6               66              0

# %%
calls['is_connection'].sum()
# Out:
# 7

# %%
calls['time_diff'] = (calls['end_date'] - calls['agent_date']).dt.seconds
calls
# Out:
#    client_id          agent_date          created_at            end_date  \
# 0        460 2013-12-17 04:55:39 2013-12-17 04:55:44 2013-12-17 04:55:45
# 1         12 2013-12-16 20:03:20 2013-12-16 20:03:22 2013-12-16 20:07:13
# 2         56 2013-12-16 20:03:20 2013-12-16 20:03:20 2013-12-16 20:05:04
# 3        980 2013-12-16 20:03:20 2013-12-16 20:03:27 2013-12-16 20:03:29
# 4        396 2013-12-16 20:08:27 2013-12-16 20:08:28 2013-12-16 20:12:03
# 5        449 2013-12-16 20:03:20 2013-12-16 20:03:25 2013-12-16 20:05:00
# 6        397 2013-12-16 20:08:25 2013-12-16 20:08:27 2013-12-16 20:09:59
# 7        398 2013-12-16 20:01:23 2013-12-16 20:01:23 2013-12-16 20:04:58
# 8        452 2013-12-16 20:03:20 2013-12-16 20:03:21 2013-12-16 20:04:55
# 9        440 2013-12-16 20:03:20 2013-12-16 20:04:26 2013-12-16 20:04:32
#
#    duration  time_connection  is_connection  time_diff
# 0         1                5              0          6
# 1       231                2              1        233
# 2       104                0              1        104
# 3         2                7              0          9
# 4       215                1              1        216
# 5        95                5              1        100
# 6        92                2              1         94
# 7       215                0              1        215
# 8        94                1              1         95
# 9         6               66              0         72

# %%
calls['time_diff'].sum()
# Out:
# 1144

# %%
calls = calls.drop(columns=['agent_date', 'created_at' ,'end_date'], axis=1)

# %%
data['year'] = pd.to_datetime(data['year'], errors = 'coerce')

# %%
data['years_diff'] = (pd.to_datetime('2022-01-12') - data['year']).dt.days
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129967                                 unknown      90  75.000000
# 129968                                   Kritt      90  30.000000
# 129969                                 unknown      90  32.000000
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro              unknown          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel              unknown  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  ... price_round       year is_usa  is_france  \
# 0               @kerinokeefe  ...          35 2013-01-01      0          0
# 1                 @vossroger  ...          15 2011-01-01      0          0
# 2                @paulgwine   ...          14 2013-01-01      1          0
# 3                    unknown  ...          13 2013-01-01      1          0
# 4                @paulgwine   ...          65 2012-01-01      1          0
# ...                      ...  ...         ...        ...    ...        ...
# 129966               unknown  ...          28 2013-01-01      0          0
# 129967           @paulgwine   ...          75 2004-01-01      1          0
# 129968            @vossroger  ...          30 2013-01-01      0          1
# 129969            @vossroger  ...          32 2012-01-01      0          1
# 129970            @vossroger  ...          21 2012-01-01      0          1
#
#        is_italy  old_wine                locality   population       area  \
# 0             1         0                    Etna   59,097,904   301230.0
# 1             0         0                   Douro   10,347,892    92391.0
# 2             0         0       Willamette Valley  333,022,386  9372610.0
# 3             0         0     Lake Michigan Shore  333,022,386  9372610.0
# 4             0         0       Willamette Valley  333,022,386  9372610.0
# ...         ...       ...                     ...          ...        ...
# 129966        0         0  Erben Müller-Burggraef   83,129,285   357022.0
# 129967        0         1                  Oregon  333,022,386  9372610.0
# 129968        0         0                  Alsace   68,035,000   547030.0
# 129969        0         0                  Alsace   68,035,000   547030.0
# 129970        0         0                  Alsace   68,035,000   547030.0
#
#        years_diff
# 0          3298.0
# 1          4029.0
# 2          3298.0
# 3          3298.0
# 4          3664.0
# ...           ...
# 129966     3298.0
# 129967     6586.0
# 129968     3298.0
# 129969     3664.0
# 129970     3664.0
#
# [129972 rows x 23 columns]

# %%
round(data['years_diff'].max())
# Out:
# 98627

# %%
clothing_list = [
    ['xxs', 'dress'],
    ['xxs', 'skirt'],
    ['xs', 'dress'],
    ['s', 'skirt'],
    ['m', 'dress'],
    ['l', 'shirt'],
    ['s', 'coat'],
    ['m', 'coat'],
    ['xxl', 'shirt'],
    ['l', 'dress']
]

clothing = pd.DataFrame(clothing_list, columns = ['size',  'type'])
clothing
# Out:
#   size   type
# 0  xxs  dress
# 1  xxs  skirt
# 2   xs  dress
# 3    s  skirt
# 4    m  dress
# 5    l  shirt
# 6    s   coat
# 7    m   coat
# 8  xxl  shirt
# 9    l  dress

# %%
ord_encoder = ce.OrdinalEncoder()
data_bin = ord_encoder.fit_transform(clothing[['size']])
clothing = pd.concat([clothing, data_bin], axis=1)

clothing
# Out:
#    size   type  size
# 0   xxs  dress     1
# 1   xxs  skirt     1
# 2    xs  dress     2
# 3     s  skirt     3
# 4     m  dress     4
# 5     l  shirt     5
# 6     s   coat     3
# 7     m   coat     4
# 8   xxl  shirt     6
# 9     l  dress     5

# %%
data = pd.read_csv('data/wine_cleared.csv')
regex = '\d{4}' # регулярное выражение для нахождения чисел
data['year'] = data['title'].str.findall(regex).str.get(0)
data = data.sort_values(by='year', ascending=True)
ord_encoder = ce.OrdinalEncoder()
data_bin = ord_encoder.fit_transform(data[['year']])
data = pd.concat([data, data_bin], axis=1)
data
# Out:
#         Unnamed: 0    country  \
# 30001        30001         US
# 77996        77996         US
# 53228        53228         US
# 83509        83509  Argentina
# 127114      127114  Argentina
# ...            ...        ...
# 129710      129710         US
# 129719      129719     France
# 129743      129743     France
# 129869      129869         US
# 129929      129929      Italy
#
#                                               description  \
# 30001   This approachable wine from the Fetzer organiz...
# 77996   Exotically fruity with an enticing floral char...
# 53228   Flavors of green hay, tart juniper berry and g...
# 83509   A little rough on the nose, but under the crus...
# 127114  Rather bland and done up with butterscotch and...
# ...                                                   ...
# 129710  Dark and intriguing, this wine offers notes of...
# 129719  In order to maintain freshness and crispness i...
# 129743  Crisp and fruity, this mature-tasting wine has...
# 129869  This wine hits the mark, combining intriguing ...
# 129929  This luminous sparkler has a sweet, fruit-forw...
#
#                             designation  points  price          province  \
# 30001               Bourbon Barrel Aged      91   19.0        California
# 77996   Bourbon Barrel Aged Batch No 13      90   19.0        California
# 53228                           unknown      88   25.0        California
# 83509                           unknown      86   20.0  Mendoza Province
# 127114                          unknown      83   20.0  Mendoza Province
# ...                                 ...     ...    ...               ...
# 129710                          unknown      86   11.0          Virginia
# 129719     Domaine Vieilles Vignes Brut      90   49.0         Champagne
# 129743                     Réserve Brut      90   70.0         Champagne
# 129869                             Brut      90   25.0        California
# 129929                          unknown      91   38.0            Veneto
#
#                               region_1        taster_name  \
# 30001                        Mendocino         Jim Gordon
# 77996                       California         Jim Gordon
# 53228                       Rutherford            unknown
# 83509                        Tupungato  Michael Schachner
# 127114                       Tupungato  Michael Schachner
# ...                                ...                ...
# 129710                        Virginia            unknown
# 129719                       Champagne         Roger Voss
# 129743                       Champagne         Roger Voss
# 129869                      California         Jim Gordon
# 129929  Prosecco Superiore di Cartizze            unknown
#
#        taster_twitter_handle  \
# 30001       @gordone_cellars
# 77996       @gordone_cellars
# 53228                unknown
# 83509            @wineschach
# 127114           @wineschach
# ...                      ...
# 129710               unknown
# 129719            @vossroger
# 129743            @vossroger
# 129869      @gordone_cellars
# 129929               unknown
#
#                                                     title          variety  \
# 30001   1000 Stories 2013 Bourbon Barrel Aged Zinfande...        Zinfandel
# 77996   1000 Stories 2014 Bourbon Barrel Aged Batch No...        Zinfandel
# 53228        1070 Green 2011 Sauvignon Blanc (Rutherford)  Sauvignon Blanc
# 83509                   Ikal 1150 2007 Malbec (Tupungato)           Malbec
# 127114              Ikal 1150 2007 Chardonnay (Tupungato)       Chardonnay
# ...                                                   ...              ...
# 129710       Molliver Vineyards NV Chambourcin (Virginia)      Chambourcin
# 129719  Bruno Gobillard NV Domaine Vieilles Vignes Bru...  Champagne Blend
# 129743             Castelnau NV Réserve Brut  (Champagne)  Champagne Blend
# 129869     Biltmore Estate NV Brut Sparkling (California)  Sparkling Blend
# 129929  Col Vetoraz Spumanti NV  Prosecco Superiore di...         Prosecco
#
#                       winery  year  year
# 30001           1000 Stories  1000     1
# 77996           1000 Stories  1000     1
# 53228             1070 Green  1070     2
# 83509              Ikal 1150  1150     3
# 127114             Ikal 1150  1150     3
# ...                      ...   ...   ...
# 129710    Molliver Vineyards   NaN    92
# 129719       Bruno Gobillard   NaN    92
# 129743             Castelnau   NaN    92
# 129869       Biltmore Estate   NaN    92
# 129929  Col Vetoraz Spumanti   NaN    92
#
# [129971 rows x 15 columns]

# %%
data = pd.read_csv('data/wine_cleared.csv')
regex = '\d{4}' # регулярное выражение для нахождения чисел
data['year'] = data['title'].str.findall(regex).str.get(0)
ord_encoder = ce.OrdinalEncoder(cols=['year'])
year_col = ord_encoder.fit_transform(data['year'])
data = pd.concat([data, year_col], axis=1)
data
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points      price  \
# 0                                 Vulkà Bianco      87  35.363389
# 1                                     Avidagos      87  15.000000
# 2                                      unknown      87  14.000000
# 3                         Reserve Late Harvest      87  13.000000
# 4           Vintner's Reserve Wild Child Block      87  65.000000
# ...                                        ...     ...        ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90  28.000000
# 129967                                 unknown      90  75.000000
# 129968                                   Kritt      90  30.000000
# 129969                                 unknown      90  32.000000
# 129970           Lieu-dit Harth Cuvée Caroline      90  21.000000
#
#                  province             region_1         taster_name  \
# 0       Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1                   Douro              unknown          Roger Voss
# 2                  Oregon    Willamette Valley        Paul Gregutt
# 3                Michigan  Lake Michigan Shore  Alexander Peartree
# 4                  Oregon    Willamette Valley        Paul Gregutt
# ...                   ...                  ...                 ...
# 129966              Mosel              unknown  Anna Lee C. Iijima
# 129967             Oregon               Oregon        Paul Gregutt
# 129968             Alsace               Alsace          Roger Voss
# 129969             Alsace               Alsace          Roger Voss
# 129970             Alsace               Alsace          Roger Voss
#
#        taster_twitter_handle  \
# 0               @kerinokeefe
# 1                 @vossroger
# 2                @paulgwine
# 3                    unknown
# 4                @paulgwine
# ...                      ...
# 129966               unknown
# 129967           @paulgwine
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery  year  year
# 0                                        Nicosia  2013     1
# 1                            Quinta dos Avidagos  2011     2
# 2                                      Rainstorm  2013     1
# 3                                     St. Julian  2013     1
# 4                                   Sweet Cheeks  2012     3
# ...                                          ...   ...   ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)  2013     1
# 129967                                  Citation  2004    12
# 129968                           Domaine Gresser  2013     1
# 129969                      Domaine Marcel Deiss  2012     3
# 129970                          Domaine Schoffit  2012     3
#
# [129971 rows x 15 columns]

# %%
encoder = ce.OneHotEncoder(cols=['type'], use_cat_names=True) # указываем столбец для кодирования
type_bin = encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
#    size   type  size  type_dress  type_skirt  type_shirt  type_coat
# 0   xxs  dress     1           1           0           0          0
# 1   xxs  skirt     1           0           1           0          0
# 2    xs  dress     2           1           0           0          0
# 3     s  skirt     3           0           1           0          0
# 4     m  dress     4           1           0           0          0
# 5     l  shirt     5           0           0           1          0
# 6     s   coat     3           0           0           0          1
# 7     m   coat     4           0           0           0          1
# 8   xxl  shirt     6           0           0           1          0
# 9     l  dress     5           1           0           0          0

# %%
clothing_dummies = pd.get_dummies(clothing, columns=['type'])
clothing_dummies
# Out:
#    size  size  type_coat  type_dress  type_shirt  type_skirt
# 0   xxs     1          0           1           0           0
# 1   xxs     1          0           0           0           1
# 2    xs     2          0           1           0           0
# 3     s     3          0           0           0           1
# 4     m     4          0           1           0           0
# 5     l     5          0           0           1           0
# 6     s     3          1           0           0           0
# 7     m     4          1           0           0           0
# 8   xxl     6          0           0           1           0
# 9     l     5          0           1           0           0

# %%
encoder = ce.OneHotEncoder(cols=['taster_name'], use_cat_names=True) # указываем столбец для кодирования
taster_bin = encoder.fit_transform(data['taster_name'])
data = pd.concat([data, taster_bin], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      129971 non-null  int64
#  1   country                         129908 non-null  object
#  2   description                     129971 non-null  object
#  3   designation                     129971 non-null  object
#  4   points                          129971 non-null  int64
#  5   price                           129971 non-null  float64
#  6   province                        129908 non-null  object
#  7   region_1                        129971 non-null  object
#  8   taster_name                     129971 non-null  object
#  9   taster_twitter_handle           129971 non-null  object
#  10  title                           129971 non-null  object
#  11  variety                         129970 non-null  object
#  12  winery                          129971 non-null  object
#  13  year                            125362 non-null  object
#  14  year                            129971 non-null  int32
#  15  taster_name_Kerin O’Keefe       129971 non-null  int64
#  16  taster_name_Roger Voss          129971 non-null  int64
#  17  taster_name_Paul Gregutt        129971 non-null  int64
#  18  taster_name_Alexander Peartree  129971 non-null  int64
#  19  taster_name_Michael Schachner   129971 non-null  int64
#  20  taster_name_Anna Lee C. Iijima  129971 non-null  int64
#  21  taster_name_Virginie Boone      129971 non-null  int64
#  22  taster_name_Matt Kettmann       129971 non-null  int64
#  23  taster_name_unknown             129971 non-null  int64
#  24  taster_name_Sean P. Sullivan    129971 non-null  int64
#  25  taster_name_Jim Gordon          129971 non-null  int64
#  26  taster_name_Joe Czerwinski      129971 non-null  int64
#  27  taster_name_Anne Krebiehl MW    129971 non-null  int64
#  28  taster_name_Lauren Buzzeo       129971 non-null  int64
#  29  taster_name_Mike DeSimone       129971 non-null  int64
#  30  taster_name_Jeff Jenssen        129971 non-null  int64
#  31  taster_name_Susan Kostrzewa     129971 non-null  int64
#  32  taster_name_Carrie Dykes        129971 non-null  int64
#  33  taster_name_Fiona Adams         129971 non-null  int64
#  34  taster_name_Christina Pickard   129971 non-null  int64
# dtypes: float64(1), int32(1), int64(22), object(11)
# memory usage: 34.2+ MB

# %%
bin_encoder = ce.BinaryEncoder(cols=['type']) # указываем столбец для кодирования
type_bin = bin_encoder.fit_transform(clothing['type'])
clothing = pd.concat([clothing, type_bin], axis=1)

clothing
# Out:
#   size   type  type_0  type_1  type_2
# 0  xxs  dress       0       0       1
# 1  xxs  skirt       0       1       0
# 2   xs  dress       0       0       1
# 3    s  skirt       0       1       0
# 4    m  dress       0       0       1
# 5    l  shirt       0       1       1
# 6    s   coat       1       0       0
# 7    m   coat       1       0       0
# 8  xxl  shirt       0       1       1
# 9    l  dress       0       0       1

# %%
data = pd.read_csv('data/wine_cleared.csv')
bin_encoder = ce.BinaryEncoder(cols=['country']) # указываем столбец для кодирования
country_bin = bin_encoder.fit_transform(data['country'])
data = pd.concat([data, country_bin], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            129971 non-null  object
#  4   points                 129971 non-null  int64
#  5   price                  129971 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               129971 non-null  object
#  8   taster_name            129971 non-null  object
#  9   taster_twitter_handle  129971 non-null  object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
#  13  country_0              129971 non-null  int64
#  14  country_1              129971 non-null  int64
#  15  country_2              129971 non-null  int64
#  16  country_3              129971 non-null  int64
#  17  country_4              129971 non-null  int64
#  18  country_5              129971 non-null  int64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 18.8+ MB

# %%
data = pd.read_csv('data/wine_cleared.csv')
bin_encoder = ce.BinaryEncoder(cols=['taster_twitter_handle']) # указываем столбец для кодирования
twitter_bin = bin_encoder.fit_transform(data['taster_twitter_handle'])
data = pd.concat([data, twitter_bin], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               129971 non-null  int64
#  1   country                  129908 non-null  object
#  2   description              129971 non-null  object
#  3   designation              129971 non-null  object
#  4   points                   129971 non-null  int64
#  5   price                    129971 non-null  float64
#  6   province                 129908 non-null  object
#  7   region_1                 129971 non-null  object
#  8   taster_name              129971 non-null  object
#  9   taster_twitter_handle    129971 non-null  object
#  10  title                    129971 non-null  object
#  11  variety                  129970 non-null  object
#  12  winery                   129971 non-null  object
#  13  taster_twitter_handle_0  129971 non-null  int64
#  14  taster_twitter_handle_1  129971 non-null  int64
#  15  taster_twitter_handle_2  129971 non-null  int64
#  16  taster_twitter_handle_3  129971 non-null  int64
#  17  taster_twitter_handle_4  129971 non-null  int64
# dtypes: float64(1), int64(7), object(10)
# memory usage: 17.8+ MB

# %%
list_of_dicts = [
 {'product': 'Product1', 'price': 1200, 'payment_type': 'Mastercard'},
 {'product': 'Product2', 'price': 3600, 'payment_type': 'Visa'},
 {'product': 'Product3', 'price': 7500, 'payment_type': 'Amex'}
]
df = pd.DataFrame(list_of_dicts)

df
# Out:
#     product  price payment_type
# 0  Product1   1200   Mastercard
# 1  Product2   3600         Visa
# 2  Product3   7500         Amex

# %%
encoder = ce.OneHotEncoder(cols=['product','payment_type']) # указываем столбец для кодирования
cols_bin = encoder.fit_transform(df[['product','payment_type']])
df = pd.concat([df, cols_bin], axis=1)

df
# Out:
#     product  price payment_type  product_1  product_2  product_3  \
# 0  Product1   1200   Mastercard          1          0          0
# 1  Product2   3600         Visa          0          1          0
# 2  Product3   7500         Amex          0          0          1
#
#    payment_type_1  payment_type_2  payment_type_3
# 0               1               0               0
# 1               0               1               0
# 2               0               0               1

# %%
import numpy as np 
import pandas as pd

np.random.seed(34)

# для нормализации, стандартизации
from sklearn import preprocessing

# Для графиков
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
matplotlib.style.use('ggplot')

# сгенерируем датасет из случайных чисел
df = pd.DataFrame({ 
    # Бета распределение, 5 – значение альфа, 1 – значение бета, 1000 – размер
    'beta': np.random.beta(5, 1, 1000) * 60,
    
    # Экспоненциальное распределение, 10 – "резкость" экспоненты, 1000 – размер
    'exponential': np.random.exponential(10, 1000),
    
    # Нормальное распределение, 10 – среднее значение р., 2 – стандартное отклонение, 1000 – количество сэмплов
    'normal_p': np.random.normal(10, 2, 1000),
    
    # Нормальное распределение, 10 – среднее значение р., 10 – стандартное отклонение, 1000 – количество сэмплов
    'normal_l': np.random.normal(10, 10, 1000),
})

# Копируем названия столбцов, которые теряются при использовании fit_transform()
col_names = list(df.columns)

# %%
# зададим параметры холста, название и визуализируем кривые распределения:
fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Исходные распределения')

# kdeplot() (KDE – оценка плотности ядра) – специальный метод для графиков распределений
sns.kdeplot(df['beta'], ax=ax1, label ='beta')
sns.kdeplot(df['exponential'], ax=ax1, label ='exponential')
sns.kdeplot(df['normal_p'], ax=ax1, label ='normal_p')
sns.kdeplot(df['normal_l'], ax=ax1, label ='normal_l')
plt.legend()

# %%
df.describe()
# Out:
#               beta  exponential     normal_p     normal_l
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.024249    10.028387     9.994006    10.175745
# std       8.474545     9.733928     2.013971    10.104004
# min      13.854022     0.007617     2.356844   -19.539980
# 25%      45.793283     2.951421     8.687478     3.566822
# 50%      52.337504     7.018565     9.983498    10.326331
# 75%      56.722191    14.022485    11.306914    16.615057
# max      59.990640    71.344341    16.214364    42.072915

# %%
# инициализируем нормализатор MinMaxScaler
mm_scaler = preprocessing.MinMaxScaler()

# кодируем исходный датасет
df_mm = mm_scaler.fit_transform(df)

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
df_mm = pd.DataFrame(df_mm, columns=col_names)

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('После нормализации MinMaxScaler')

sns.kdeplot(df_mm['beta'], ax=ax1)
sns.kdeplot(df_mm['exponential'], ax=ax1)
sns.kdeplot(df_mm['normal_p'], ax=ax1)
sns.kdeplot(df_mm['normal_l'], ax=ax1)
# Out:
# <AxesSubplot: title={'center': 'После нормализации MinMaxScaler'}, xlabel='beta', ylabel='Density'>

# %%
df_mm.describe()
# Out:
#               beta  exponential     normal_p     normal_l
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.783981     0.140471     0.551120     0.482297
# std       0.183684     0.136450     0.145334     0.163992
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.692276     0.041266     0.456837     0.375032
# 50%       0.834120     0.098280     0.550362     0.484741
# 75%       0.929157     0.196461     0.645864     0.586810
# max       1.000000     1.000000     1.000000     1.000000

# %%
# инициализируем нормализатор RobustScaler
r_scaler = preprocessing.RobustScaler()

# кодируем исходный датасет
df_r = r_scaler.fit_transform(df)

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
df_r = pd.DataFrame(df_r, columns=col_names)

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Распределения после RobustScaler')

sns.kdeplot(df_r['beta'], ax=ax1)
sns.kdeplot(df_r['exponential'], ax=ax1)
sns.kdeplot(df_r['normal_p'], ax=ax1)
sns.kdeplot(df_r['normal_l'], ax=ax1)
# Out:
# <AxesSubplot: title={'center': 'Распределения после RobustScaler'}, xlabel='beta', ylabel='Density'>

# %%
df_r.describe()
# Out:
#                beta   exponential      normal_p     normal_l
# count  1.000000e+03  1.000000e+03  1.000000e+03  1000.000000
# mean  -2.116639e-01  2.718638e-01  4.011529e-03    -0.011541
# std    7.754247e-01  8.792225e-01  7.688570e-01     0.774358
# min   -3.521256e+00 -6.332678e-01 -2.911564e+00    -2.288916
# 25%   -5.987992e-01 -3.673671e-01 -4.947706e-01    -0.518040
# 50%    3.252607e-16 -4.011548e-17  3.390842e-16     0.000000
# 75%    4.012008e-01  6.326329e-01  5.052294e-01     0.481960
# max    7.002654e-01  5.810261e+00  2.378706e+00     2.433017

# %%
# инициализируем стандартизатор StandardScaler
s_scaler = preprocessing.StandardScaler()

# кодируем исходный датасет
df_s = s_scaler.fit_transform(df)

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
df_s = pd.DataFrame(df_s, columns=col_names)

fig, (ax1) = plt.subplots(ncols=1, figsize=(10, 8))
ax1.set_title('Распределения после StandardScaler')

sns.kdeplot(df_s['beta'], ax=ax1)
sns.kdeplot(df_s['exponential'], ax=ax1)
sns.kdeplot(df_s['normal_p'], ax=ax1)
sns.kdeplot(df_s['normal_l'], ax=ax1)
# Out:
# <AxesSubplot: title={'center': 'Распределения после StandardScaler'}, xlabel='beta', ylabel='Density'>

# %%
df_s.describe()
# Out:
#                beta   exponential      normal_p      normal_l
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   6.075140e-16 -1.776357e-18  8.100187e-16 -2.398082e-17
# std    1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# min   -4.270238e+00 -1.029983e+00 -3.793988e+00 -2.942457e+00
# 25%   -4.995057e-01 -7.274049e-01 -6.490566e-01 -6.544169e-01
# 50%    2.731017e-01 -3.093641e-01 -5.220134e-03  1.491105e-02
# 75%    7.907555e-01  4.105327e-01  6.522262e-01  6.376219e-01
# max    1.176627e+00  6.302351e+00  3.090149e+00  3.158464e+00

# %%
data = pd.read_csv('data/wine_cleared.csv')
r_scaler = preprocessing.RobustScaler()
price_scaled = r_scaler.fit_transform(data[['price']])
price_scaled = pd.DataFrame(price_scaled, columns=['price'])
display(price_scaled.describe())
display(round(price_scaled['price'].sum()))
# Out:
#                price
# count  129971.000000
# mean        0.334700
# std         1.798958
# min        -1.090909
# 25%        -0.454545
# 50%         0.000000
# 75%         0.545455
# max       148.727273
# 43501

# %%
data = pd.read_csv('data/wine_cleared.csv')
s_scaler = preprocessing.StandardScaler()
price_scaled = s_scaler.fit_transform(data[['price']])
price_scaled = pd.DataFrame(price_scaled, columns=['price'])
display(price_scaled.describe())
display(round(price_scaled['price'][129968], 2))
# Out:
#               price
# count  1.299710e+05
# mean  -2.520256e-17
# std    1.000004e+00
# min   -7.924668e-01
# 25%   -4.387252e-01
# 50%   -1.860526e-01
# 75%    1.171544e-01
# max    8.248841e+01
# -0.14

# %%
iris = pd.read_csv('data/iris.csv')
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.heatmap(iris.corr(), annot=True)
# Out:
# C:\Users\kkaza\AppData\Local\Temp\ipykernel_14240\1307137915.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(), annot=True)
# <AxesSubplot: >

# %%
iris = iris.drop(['petal.width'], axis=1)
iris = iris.drop(['petal.length'], axis=1)

# %%
iris.head()
# Out:
#    sepal.length  sepal.width variety
# 0           5.1          3.5  Setosa
# 1           4.9          3.0  Setosa
# 2           4.7          3.2  Setosa
# 3           4.6          3.1  Setosa
# 4           5.0          3.6  Setosa
